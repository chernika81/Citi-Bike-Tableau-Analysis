# %%
# import pandas
import pandas as pd

# %%
# merging csv files
df = pd.concat(
    map(pd.read_csv, ["JC-202212-citibike-tripdata.csv", "JC-202201-citibike-tripdata.csv", "JC-202202-citibike-tripdata.csv", "JC-202203-citibike-tripdata.csv", "JC-202204-citibike-tripdata.csv", "JC-202205-citibike-tripdata.csv", "JC-202206-citibike-tripdata.csv", "JC-202207-citbike-tripdata.csv", "JC-202208-citibike-tripdata.csv", "JC-202209-citibike-tripdata.csv", "JC-202210-citibike-tripdata.csv", "JC-202211-citibike-tripdata.csv"]), ignore_index=True)
df
# Out:
#                  ride_id  rideable_type           started_at  \
# 0       099D81CA71EBADAB   classic_bike  2022-12-23 16:02:26
# 1       D979F3B79FC30F1F  electric_bike  2022-12-27 10:54:29
# 2       3950909BC3B42E43   classic_bike  2022-12-31 10:39:39
# 3       372E50F5FB4FD434   classic_bike  2022-12-05 08:16:10
# 4       AB701FB8091C7431   classic_bike  2022-12-02 13:40:36
# ...                  ...            ...                  ...
# 895480  5CD09DFD050326DF   classic_bike  2022-11-04 15:42:11
# 895481  99BEB76F3AF420D6   classic_bike  2022-11-13 11:42:30
# 895482  784CC6A8F182DE26  electric_bike  2022-11-05 01:33:31
# 895483  E3CBD5C6006BE3E2   classic_bike  2022-11-18 19:11:27
# 895484  DBDEE1728FAA6730   classic_bike  2022-11-07 17:43:50
#
#                    ended_at                      start_station_name  \
# 0       2022-12-23 16:09:40  Mama Johnson Field - 4 St & Jackson St
# 1       2022-12-27 10:59:23                            Jersey & 3rd
# ...

# %%
# Save the dataframe to a CSV file
df.to_csv("JC_2022_citibike-tripdata_total.csv", index=False)
